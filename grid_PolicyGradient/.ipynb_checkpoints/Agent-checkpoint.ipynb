# %%
import copy
import pylab
import numpy as np
import time
import sys
from env2 import Env
from keras.layers import Dense
from keras.optimizers import Adam
#from keras.optimizers import SGD
from keras.models import Sequential
from keras import backend as K
# %run env2.py

EPISODES = 2500
number_agents = 2

# this is RL agent for the GridWorld
class ReinforceAgent:
    def __init__(self, agentNr):
        self.load_model = False
        # actions which agent can do [l,r,u,d,ss]
        self.action_space = [0, 1, 2, 3, 4]
        # get size of state and action
        self.action_size = len(self.action_space)
        self.state_size = 18
        self.discount_factor = 0.99
        self.learning_rate = 0.001

        self.model = self.build_model()
        self.optimizer = self.optimizer()
        self.states, self.actions, self.rewards = [], [], []

        if self.load_model and agentNr == 0:
            self.model.load_weights('./save_model/reinforce_new1.h5')
        elif self.load_model and agentNr == 1:
            self.model.load_weights('./save_model/reinforce_new2.h5')
            

    # state is input and probability of each action(policy) is output of network
    def build_model(self):
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(self.action_size, activation='softmax'))
        model.summary()
        return model

    # create error function and training function to update policy network
    def optimizer(self):
        action = K.placeholder(shape=[None, 5])
        discounted_rewards = K.placeholder(shape=[None, ])

        # Calculate cross entropy error function
        action_prob = K.sum(action * self.model.output, axis=1)
        cross_entropy = K.log(action_prob) * discounted_rewards
        loss = -K.sum(cross_entropy)

        # create training function
        optimizer = Adam(lr=self.learning_rate)
        #optimizer = SGD(lr=0.01, clipvalue=0.5)
        updates = optimizer.get_updates(self.model.trainable_weights, [],
                                        loss)
        train = K.function([self.model.input, action, discounted_rewards], [],
                           updates=updates)

        return train

    # get action from policy network, see np.random.choice instructions
    def get_action(self, state):
        policy = self.model.predict(state)[0]
        return np.random.choice(self.action_size, 1, p=policy)[0] 

    # calculate discounted rewards
    def discount_rewards(self, rewards):
        discounted_rewards = np.zeros_like(rewards)
        running_add = 0
        for t in reversed(range(0, len(rewards))):
            running_add = running_add * self.discount_factor + rewards[t]
            discounted_rewards[t] = running_add
        return discounted_rewards

    # save states, actions and rewards for an episode
    def append_sample(self, state, action, reward):
        self.states.append(state[0])
        self.rewards.append(reward)
        act = np.zeros(self.action_size)
        act[action] = 1
        self.actions.append(act)

    # update policy neural network
    def train_model(self):
        discounted_rewards = np.float32(self.discount_rewards(self.rewards))
        discounted_rewards -= np.mean(discounted_rewards)
        discounted_rewards /= np.std(discounted_rewards)

        self.optimizer([self.states, self.actions, discounted_rewards])
        self.states, self.actions, self.rewards = [], [], []


if __name__ == "__main__":
    
    env = Env()
    
    agents = []
    agents.append(ReinforceAgent(0))
    agents.append(ReinforceAgent(1))

    global_step = 0
    scores, episodes = [], []

    for e in range(EPISODES):
        episodes.append(e+1)
        done = [False]*number_agents
        score = [0]*number_agents
        # fresh env
        state = [env.reset(0), env.reset(1)]
        state[0] = np.reshape(state[0], [1, 18])
        state[1] = np.reshape(state[1], [1, 18])

        while (done[0] == False or done[1] == False):
            for agent in agents:
                t0 = time.time()
                start = time.time()
                i = agents.index(agent)
                if done[i]:
                    continue
                global_step += 1
                # get action for the current state and go one step in environment
                action = agent.get_action(state[i])
                next_state, reward, done[i] = env.step(action, i)
                next_state = np.reshape(next_state, [1, 18])

                agent.append_sample(state[i], action, reward)
                score[i] += reward
                state[i] = copy.deepcopy(next_state)
                
                end = time.time()
                #print(end-start)
                
                if done[i]:
                # update policy neural network for each episode
                    agent.train_model()
                    #scores.append(score)
                    #episodes.append(e)
                    score[i] = round(score[i], 2)
                    if e % 100 == 0:
                        print("Episode:", e, " score for agent ",i+1,":",score[i], "at time_step:", global_step)
                t1 = time.time()
                #print(t1-t0)
        
        scores.append(score)
        if e % 100 == 0:
    
            agents[0].model.save_weights("./save_model/reinforce_new1.h5")
            agents[1].model.save_weights("./save_model/reinforce_new2.h5")
            if e ==2500:
                close()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 24)                456
# _________________________________________________________________
# dense_8 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 125
# =================================================================
# Total params: 1,181
# Trainable params: 1,181
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 24)                456
# _________________________________________________________________
# dense_11 (Dense)             (None, 24)                600
# _________________________________________________________________
# dense_12 (Dense)             (None, 5)                 125
# =================================================================
# Total params: 1,181
# Trainable params: 1,181
# Non-trainable params: 0
# _________________________________________________________________
# Episode: 0  score for agent  1 : -7.2 at time_step: 113
# Episode: 0  score for agent  2 : -11.9 at time_step: 121
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-2-330b1a8ceac9> in <module>()
#     128                 # get action for the current state and go one step in environment
#     129                 action = agent.get_action(state[i])
# --> 130                 next_state, reward, done[i] = env.step(action, i)
#     131                 next_state = np.reshape(next_state, [1, 18])
#     132
#
# ~/Desktop/KEX/grid_PolicyGradient/env2.py in step(self, action, agentNr)
#     161
#     162         if self.counter % 2 == 1:
# --> 163             self.rewards = self.move_rewards()
#     164
#     165         next_coords = self.move(self.agents[agentNr], action)
#
# ~/Desktop/KEX/grid_PolicyGradient/env2.py in move_rewards(self)
#     216                 new_rewards.append(temp)
#     217                 continue
# --> 218             temp['coords'] = self.move_const(temp)
#     219             temp['state'] = self.coords_to_state(temp['coords'])
#     220             new_rewards.append(temp)
#
# ~/Desktop/KEX/grid_PolicyGradient/env2.py in move_const(self, target)
#     224     def move_const(self, target):
#     225
# --> 226         s = self.canvas.coords(target['figure'])
#     227
#     228         base_action = np.array([0, 0])
#
# ~/anaconda3/lib/python3.6/tkinter/__init__.py in coords(self, *args)
#    2461         return [self.tk.getdouble(x) for x in
#    2462                            self.tk.splitlist(
# -> 2463                    self.tk.call((self._w, 'coords') + args))]
#    2464     def _create(self, itemType, args, kw): # Args: (val, val, ..., cnf={})
#    2465         """Internal function."""
#
# TclError: invalid command name ".!canvas"

# %% [markdown]
# # Plot test

# %%
import pylab
import pickle

#with open('outfile', 'wb') as fp:
    #pickle.dump(itemlist, fp)

with open ('./save_data/episodes', 'rb') as fp:
    episodes = pickle.load(fp)
with open ('./save_data/pickle1', 'rb') as fp:
    scores = pickle.load(fp)
    
s1 = []
s2 = []
for i in range(0, 2500):
    s1.append(scores[i][0])
    s2.append(scores[i][1])
    
#s2_new = [i * 1.43 for i in s2]

pylab.plot(episodes, s1, 'b', linewidth=0.1)
pylab.plot(episodes, s2, 'g', linewidth=0.1)
pylab.xlabel('episodes')
pylab.ylabel('reward')
pylab.title('Reward as function of episodes')
pylab.legend(('Agent 1', 'Agent 2'),
           loc='upper right')

pylab.savefig('./save_graph/pickle1.eps', format='eps', dpi=900)

# %% [markdown]
# # Saving/writing lists

# %%
import pickle

with open('./save_data/pickle1', 'wb') as fp:
    pickle.dump(scores, fp)
#with open ('./save_data/test', 'rb') as fp:
   # list_name = pickle.load(fp)

# %% [markdown]
# # Comparing SGD and Adam

# %%
import pylab
import pickle

#with open('outfile', 'wb') as fp:
    #pickle.dump(itemlist, fp)

with open ('episodes', 'rb') as fp:
    episodes = pickle.load(fp)
with open ('SGD', 'rb') as fp:
    scores = pickle.load(fp)
    
s1 = []
s2 = []
for i in range(0, 2500):
    s1.append(scores[i][0])
    s2.append(scores[i][1])

s1_new = [i * 1.43 for i in s1]
    
    
pylab.plot(episodes, s1, 'b', linewidth=0.1)
pylab.plot(episodes, s2, 'g', linewidth=0.1)
pylab.xlabel('episodes')
pylab.ylabel('reward')
pylab.title('Reward as function of episodes (Total steps = 107374)')
pylab.legend(('Agent 1', 'Agent 2'),
           loc='upper right')

pylab.savefig('./save_graph/SGD.eps', format='eps', dpi=900)

# %%
print(global_step)
